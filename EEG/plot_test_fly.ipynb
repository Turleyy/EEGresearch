# %%
import sympy as sym
import numpy as np
import matplotlib.pyplot as plt

# %%
x = np.linspace(-2,2,41)
y = 2 + np.sqrt(abs(x))
plt.plot(x,y,'ms-')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
X_data = np.random.random(100) * 10
Y_data = np.random.random(100) * 10

plt.scatter(X_data, Y_data, c="#00f", s=100, alpha=0.5)
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
